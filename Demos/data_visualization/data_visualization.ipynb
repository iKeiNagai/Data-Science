# %% [markdown]
# # Data Visualization

# %% [markdown]
# In order to visualize data for exploration, we usually use `pandas`, `matplotlib` and `seaborn` packages

# %% [markdown]
# While numerical summaries are useful for condensing information, visual summaries can provide even more context and detail in a small amount of space.

# %% [markdown]
# - Color for visualization: [Color](https://matplotlib.org/3.1.0/gallery/color/named_colors.html)
# - Color Palette in Matplotlib: [cmap Matplotlib](https://matplotlib.org/stable/tutorials/colors/colormaps.html)
# - Color Palette in Seaborn: [cmap Seaborn](https://seaborn.pydata.org/tutorial/color_palettes.html)
# - Viz with Pandas : [Pandas.DataFrame.plot()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)
# - Viz with Matplotlib: [Matplotlib plot types](https://matplotlib.org/stable/plot_types/index)
# - Viz with Seaborn: [Seaborn Plot Gallery](https://seaborn.pydata.org/examples/index.html)

# %% [markdown]
# - Histogram:
#     * df.plot.hist()
#     * plt.hist()
#     * sns.histplot()
# - Boxplot:
#     * df.plot.box()
#     * plt.boxplot()
#     * sns.boxplot()
# - Violin Plot:
#     * plt.violinplot()
#     * sns.violinplot()
# - Bee-swarm Plot:
#     * sns.swarmplot()
# - Bar Plot:
#     * df.plot.bar()
#     * plt.bar()
#     * sns.barplot()
# - Scatter Plot:
#     * df.plot.scatter()
#     * plt.scatter()
#     * sns.scatterplot()
# - Line Plot:
#     * df.plot.line()
#     * plt.plot()
#     * sns.lineplot()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Some of most useful visualization for analysis

# %% [markdown]
# - Univariate Analysis: Histogram (continuous variable), Count plot(categorical variable)
# - Bivariate Analysis: Scatter Plot
# - Whole dataset Analysis: Correlation matrix plot, Scatter Matrix
# - Check for outliers: Boxplot/Violin Plot

# %%
data=pd.read_csv('./data/world_happiness_2019.csv')
data.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# 25%                   0.547750                      0.308000    0.108750
# 50%                   0.789000                      0.417000    0.177500
# 75%                   0.881750                      0.507250    0.248250
# max                   1.141000                      0.631000    0.566000
#
#        Perceptions of corruption
# count                 156.000000
# mean                    0.110603
# std                     0.094538
# min                     0.000000
# 25%                     0.047000
# 50%                     0.085500
# 75%                     0.141250
# max                     0.453000

# %%
data.sample(6)
# Out:
#      Overall rank       Country or region  Score  GDP per capita  \
# 77             78  Bosnia and Herzegovina  5.386           0.945
# 64             65                    Peru  5.697           0.960
# 116           117                    Iran  4.548           1.100
# 99            100                   Nepal  4.913           0.446
# 71             72                   Libya  5.525           1.044
# 126           127        Congo (Kinshasa)  4.418           0.094
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 77            1.212                    0.845                         0.212
# 64            1.274                    0.854                         0.455
# 116           0.842                    0.785                         0.305
# 99            1.226                    0.677                         0.439
# 71            1.303                    0.673                         0.416
# 126           1.125                    0.357                         0.269
#
#      Generosity  Perceptions of corruption
# 77        0.263                      0.006
# 64        0.083                      0.027
# 116       0.270                      0.125
# 99        0.285                      0.089
# 71        0.133                      0.152
# 126       0.212                      0.053

# %%
# Adding categorical feature "Group": High rank, Medium rank, Low rank 
data.loc[:,'Group'] = data['Overall rank'].apply(lambda x: 'High' if x <= 52 else ('Medium' if x <= 104 else 'Low'))
data
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# 1             1.573                    0.996                         0.592
# 2             1.582                    1.028                         0.603
# 3             1.624                    1.026                         0.591
# 4             1.522                    0.999                         0.557
# ..              ...                      ...                           ...
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption Group
# 0         0.153                      0.393  High
# 1         0.252                      0.410  High
# 2         0.271                      0.341  High
# 3         0.354                      0.118  High
# 4         0.322                      0.298  High
# ..          ...                        ...   ...
# 151       0.217                      0.411   Low
# 152       0.276                      0.147   Low
# 153       0.158                      0.025   Low
# 154       0.235                      0.035   Low
# 155       0.202                      0.091   Low
#
# [156 rows x 10 columns]

# %% [markdown]
# ========================================================================================================================

# %% [markdown]
# ## Visualisation of the whole dataset: Correlation Matrix, Scatter Plot Matrix

# %% [markdown]
# ### Correlation matrix

# %%
correlation_matrix = data.select_dtypes(include=[np.number]).corr()
correlation_matrix
# Out:
#                               Overall rank     Score  GDP per capita  \
# Overall rank                      1.000000 -0.989096       -0.801947
# Score                            -0.989096  1.000000        0.793883
# GDP per capita                   -0.801947  0.793883        1.000000
# Social support                   -0.767465  0.777058        0.754906
# Healthy life expectancy          -0.787411  0.779883        0.835462
# Freedom to make life choices     -0.546606  0.566742        0.379079
# Generosity                       -0.047993  0.075824       -0.079662
# Perceptions of corruption        -0.351959  0.385613        0.298920
#
#                               Social support  Healthy life expectancy  \
# Overall rank                       -0.767465                -0.787411
# Score                               0.777058                 0.779883
# GDP per capita                      0.754906                 0.835462
# Social support                      1.000000                 0.719009
# Healthy life expectancy             0.719009                 1.000000
# Freedom to make life choices        0.447333                 0.390395
# Generosity                         -0.048126                -0.029511
# Perceptions of corruption           0.181899                 0.295283
#
#                               Freedom to make life choices  Generosity  \
# Overall rank                                     -0.546606   -0.047993
# Score                                             0.566742    0.075824
# GDP per capita                                    0.379079   -0.079662
# Social support                                    0.447333   -0.048126
# Healthy life expectancy                           0.390395   -0.029511
# Freedom to make life choices                      1.000000    0.269742
# Generosity                                        0.269742    1.000000
# Perceptions of corruption                         0.438843    0.326538
#
#                               Perceptions of corruption
# Overall rank                                  -0.351959
# Score                                          0.385613
# GDP per capita                                 0.298920
# Social support                                 0.181899
# Healthy life expectancy                        0.295283
# Freedom to make life choices                   0.438843
# Generosity                                     0.326538
# Perceptions of corruption                      1.000000

# %% [markdown]
# ### Color with conditions
# - Pandas
# - [df.style.applymap()](https://pandas.pydata.org/docs/reference/api/pandas.io.formats.style.Styler.applymap.html)

# %%
def negative_value(x, col1, col2):
    return f"color: {col1 if x < 0 else col2}"
correlation_matrix.style.map(negative_value, col1='red', col2='darkgreen')
# Out:
# <style type="text/css">
# #T_4878b_row0_col0, #T_4878b_row1_col1, #T_4878b_row1_col2, #T_4878b_row1_col3, #T_4878b_row1_col4, #T_4878b_row1_col5, #T_4878b_row1_col6, #T_4878b_row1_col7, #T_4878b_row2_col1, #T_4878b_row2_col2, #T_4878b_row2_col3, #T_4878b_row2_col4, #T_4878b_row2_col5, #T_4878b_row2_col7, #T_4878b_row3_col1, #T_4878b_row3_col2, #T_4878b_row3_col3, #T_4878b_row3_col4, #T_4878b_row3_col5, #T_4878b_row3_col7, #T_4878b_row4_col1, #T_4878b_row4_col2, #T_4878b_row4_col3, #T_4878b_row4_col4, #T_4878b_row4_col5, #T_4878b_row4_col7, #T_4878b_row5_col1, #T_4878b_row5_col2, #T_4878b_row5_col3, #T_4878b_row5_col4, #T_4878b_row5_col5, #T_4878b_row5_col6, #T_4878b_row5_col7, #T_4878b_row6_col1, #T_4878b_row6_col5, #T_4878b_row6_col6, #T_4878b_row6_col7, #T_4878b_row7_col1, #T_4878b_row7_col2, #T_4878b_row7_col3, #T_4878b_row7_col4, #T_4878b_row7_col5, #T_4878b_row7_col6, #T_4878b_row7_col7 {
#   color: darkgreen;
# }
# #T_4878b_row0_col1, #T_4878b_row0_col2, #T_4878b_row0_col3, #T_4878b_row0_col4, #T_4878b_row0_col5, #T_4878b_row0_col6, #T_4878b_row0_col7, #T_4878b_row1_col0, #T_4878b_row2_col0, #T_4878b_row2_col6, #T_4878b_row3_col0, #T_4878b_row3_col6, #T_4878b_row4_col0, #T_4878b_row4_col6, #T_4878b_row5_col0, #T_4878b_row6_col0, #T_4878b_row6_col2, #T_4878b_row6_col3, #T_4878b_row6_col4, #T_4878b_row7_col0 {
#   color: red;
# }
# </style>
# <table id="T_4878b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4878b_level0_col0" class="col_heading level0 col0" >Overall rank</th>
#       <th id="T_4878b_level0_col1" class="col_heading level0 col1" >Score</th>
#       <th id="T_4878b_level0_col2" class="col_heading level0 col2" >GDP per capita</th>
#       <th id="T_4878b_level0_col3" class="col_heading level0 col3" >Social support</th>
#       <th id="T_4878b_level0_col4" class="col_heading level0 col4" >Healthy life expectancy</th>
#       <th id="T_4878b_level0_col5" class="col_heading level0 col5" >Freedom to make life choices</th>
#       <th id="T_4878b_level0_col6" class="col_heading level0 col6" >Generosity</th>
#       <th id="T_4878b_level0_col7" class="col_heading level0 col7" >Perceptions of corruption</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4878b_level0_row0" class="row_heading level0 row0" >Overall rank</th>
#       <td id="T_4878b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4878b_row0_col1" class="data row0 col1" >-0.989096</td>
#       <td id="T_4878b_row0_col2" class="data row0 col2" >-0.801947</td>
#       <td id="T_4878b_row0_col3" class="data row0 col3" >-0.767465</td>
#       <td id="T_4878b_row0_col4" class="data row0 col4" >-0.787411</td>
#       <td id="T_4878b_row0_col5" class="data row0 col5" >-0.546606</td>
#       <td id="T_4878b_row0_col6" class="data row0 col6" >-0.047993</td>
#       <td id="T_4878b_row0_col7" class="data row0 col7" >-0.351959</td>
#     </tr>
#     <tr>
#       <th id="T_4878b_level0_row1" class="row_heading level0 row1" >Score</th>
#       <td id="T_4878b_row1_col0" class="data row1 col0" >-0.989096</td>
#       <td id="T_4878b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_4878b_row1_col2" class="data row1 col2" >0.793883</td>
#       <td id="T_4878b_row1_col3" class="data row1 col3" >0.777058</td>
#       <td id="T_4878b_row1_col4" class="data row1 col4" >0.779883</td>
#       <td id="T_4878b_row1_col5" class="data row1 col5" >0.566742</td>
#       <td id="T_4878b_row1_col6" class="data row1 col6" >0.075824</td>
#       <td id="T_4878b_row1_col7" class="data row1 col7" >0.385613</td>
#     </tr>
#     <tr>
#       <th id="T_4878b_level0_row2" class="row_heading level0 row2" >GDP per capita</th>
#       <td id="T_4878b_row2_col0" class="data row2 col0" >-0.801947</td>
#       <td id="T_4878b_row2_col1" class="data row2 col1" >0.793883</td>
#       <td id="T_4878b_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_4878b_row2_col3" class="data row2 col3" >0.754906</td>
#       <td id="T_4878b_row2_col4" class="data row2 col4" >0.835462</td>
#       <td id="T_4878b_row2_col5" class="data row2 col5" >0.379079</td>
#       <td id="T_4878b_row2_col6" class="data row2 col6" >-0.079662</td>
#       <td id="T_4878b_row2_col7" class="data row2 col7" >0.298920</td>
#     </tr>
#     <tr>
#       <th id="T_4878b_level0_row3" class="row_heading level0 row3" >Social support</th>
#       <td id="T_4878b_row3_col0" class="data row3 col0" >-0.767465</td>
#       <td id="T_4878b_row3_col1" class="data row3 col1" >0.777058</td>
#       <td id="T_4878b_row3_col2" class="data row3 col2" >0.754906</td>
#       <td id="T_4878b_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_4878b_row3_col4" class="data row3 col4" >0.719009</td>
#       <td id="T_4878b_row3_col5" class="data row3 col5" >0.447333</td>
#       <td id="T_4878b_row3_col6" class="data row3 col6" >-0.048126</td>
#       <td id="T_4878b_row3_col7" class="data row3 col7" >0.181899</td>
#     </tr>
#     <tr>
#       <th id="T_4878b_level0_row4" class="row_heading level0 row4" >Healthy life expectancy</th>
#       <td id="T_4878b_row4_col0" class="data row4 col0" >-0.787411</td>
#       <td id="T_4878b_row4_col1" class="data row4 col1" >0.779883</td>
#       <td id="T_4878b_row4_col2" class="data row4 col2" >0.835462</td>
#       <td id="T_4878b_row4_col3" class="data row4 col3" >0.719009</td>
#       <td id="T_4878b_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_4878b_row4_col5" class="data row4 col5" >0.390395</td>
#       <td id="T_4878b_row4_col6" class="data row4 col6" >-0.029511</td>
#       <td id="T_4878b_row4_col7" class="data row4 col7" >0.295283</td>
#     </tr>
#     <tr>
#       <th id="T_4878b_level0_row5" class="row_heading level0 row5" >Freedom to make life choices</th>
#       <td id="T_4878b_row5_col0" class="data row5 col0" >-0.546606</td>
#       <td id="T_4878b_row5_col1" class="data row5 col1" >0.566742</td>
#       <td id="T_4878b_row5_col2" class="data row5 col2" >0.379079</td>
#       <td id="T_4878b_row5_col3" class="data row5 col3" >0.447333</td>
#       <td id="T_4878b_row5_col4" class="data row5 col4" >0.390395</td>
#       <td id="T_4878b_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_4878b_row5_col6" class="data row5 col6" >0.269742</td>
#       <td id="T_4878b_row5_col7" class="data row5 col7" >0.438843</td>
#     </tr>
#     <tr>
#       <th id="T_4878b_level0_row6" class="row_heading level0 row6" >Generosity</th>
#       <td id="T_4878b_row6_col0" class="data row6 col0" >-0.047993</td>
#       <td id="T_4878b_row6_col1" class="data row6 col1" >0.075824</td>
#       <td id="T_4878b_row6_col2" class="data row6 col2" >-0.079662</td>
#       <td id="T_4878b_row6_col3" class="data row6 col3" >-0.048126</td>
#       <td id="T_4878b_row6_col4" class="data row6 col4" >-0.029511</td>
#       <td id="T_4878b_row6_col5" class="data row6 col5" >0.269742</td>
#       <td id="T_4878b_row6_col6" class="data row6 col6" >1.000000</td>
#       <td id="T_4878b_row6_col7" class="data row6 col7" >0.326538</td>
#     </tr>
#     <tr>
#       <th id="T_4878b_level0_row7" class="row_heading level0 row7" >Perceptions of corruption</th>
#       <td id="T_4878b_row7_col0" class="data row7 col0" >-0.351959</td>
#       <td id="T_4878b_row7_col1" class="data row7 col1" >0.385613</td>
#       <td id="T_4878b_row7_col2" class="data row7 col2" >0.298920</td>
#       <td id="T_4878b_row7_col3" class="data row7 col3" >0.181899</td>
#       <td id="T_4878b_row7_col4" class="data row7 col4" >0.295283</td>
#       <td id="T_4878b_row7_col5" class="data row7 col5" >0.438843</td>
#       <td id="T_4878b_row7_col6" class="data row7 col6" >0.326538</td>
#       <td id="T_4878b_row7_col7" class="data row7 col7" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Color the background in gradient style
#
# - Pandas
# - [df.style.background()](https://pandas.pydata.org/docs/reference/api/pandas.io.formats.style.Styler.background_gradient.html)

# %%
correlation_matrix.style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_6fe1f_row0_col0, #T_6fe1f_row1_col1, #T_6fe1f_row2_col2, #T_6fe1f_row3_col3, #T_6fe1f_row4_col4, #T_6fe1f_row5_col5, #T_6fe1f_row6_col6, #T_6fe1f_row7_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_6fe1f_row0_col1, #T_6fe1f_row0_col2, #T_6fe1f_row0_col3, #T_6fe1f_row0_col4, #T_6fe1f_row0_col5, #T_6fe1f_row0_col7, #T_6fe1f_row1_col0, #T_6fe1f_row2_col6 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_6fe1f_row0_col6, #T_6fe1f_row3_col6 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_6fe1f_row1_col2 {
#   background-color: #b2dd2d;
#   color: #000000;
# }
# #T_6fe1f_row1_col3 {
#   background-color: #aadc32;
#   color: #000000;
# }
# #T_6fe1f_row1_col4 {
#   background-color: #addc30;
#   color: #000000;
# }
# #T_6fe1f_row1_col5 {
#   background-color: #4ec36b;
#   color: #000000;
# }
# #T_6fe1f_row1_col6 {
#   background-color: #46327e;
#   color: #f1f1f1;
# }
# #T_6fe1f_row1_col7 {
#   background-color: #1e9b8a;
#   color: #f1f1f1;
# }
# #T_6fe1f_row2_col0 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_6fe1f_row2_col1 {
#   background-color: #bade28;
#   color: #000000;
# }
# #T_6fe1f_row2_col3 {
#   background-color: #a2da37;
#   color: #000000;
# }
# #T_6fe1f_row2_col4, #T_6fe1f_row4_col2 {
#   background-color: #c2df23;
#   color: #000000;
# }
# #T_6fe1f_row2_col5 {
#   background-color: #22a884;
#   color: #f1f1f1;
# }
# #T_6fe1f_row2_col7 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_6fe1f_row3_col0 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_6fe1f_row3_col1, #T_6fe1f_row4_col1 {
#   background-color: #b5de2b;
#   color: #000000;
# }
# #T_6fe1f_row3_col2 {
#   background-color: #a5db36;
#   color: #000000;
# }
# #T_6fe1f_row3_col4, #T_6fe1f_row4_col3 {
#   background-color: #95d840;
#   color: #000000;
# }
# #T_6fe1f_row3_col5 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_6fe1f_row3_col7 {
#   background-color: #2a778e;
#   color: #f1f1f1;
# }
# #T_6fe1f_row4_col0 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_6fe1f_row4_col5, #T_6fe1f_row7_col4 {
#   background-color: #24aa83;
#   color: #f1f1f1;
# }
# #T_6fe1f_row4_col6 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_6fe1f_row4_col7 {
#   background-color: #228b8d;
#   color: #f1f1f1;
# }
# #T_6fe1f_row5_col0 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_6fe1f_row5_col1 {
#   background-color: #70cf57;
#   color: #000000;
# }
# #T_6fe1f_row5_col2 {
#   background-color: #31b57b;
#   color: #f1f1f1;
# }
# #T_6fe1f_row5_col3 {
#   background-color: #3dbc74;
#   color: #f1f1f1;
# }
# #T_6fe1f_row5_col4 {
#   background-color: #32b67a;
#   color: #f1f1f1;
# }
# #T_6fe1f_row5_col6, #T_6fe1f_row7_col0 {
#   background-color: #32658e;
#   color: #f1f1f1;
# }
# #T_6fe1f_row5_col7 {
#   background-color: #20a486;
#   color: #f1f1f1;
# }
# #T_6fe1f_row6_col0 {
#   background-color: #238a8d;
#   color: #f1f1f1;
# }
# #T_6fe1f_row6_col1, #T_6fe1f_row7_col3 {
#   background-color: #1f998a;
#   color: #f1f1f1;
# }
# #T_6fe1f_row6_col2 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_6fe1f_row6_col3 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_6fe1f_row6_col4 {
#   background-color: #277e8e;
#   color: #f1f1f1;
# }
# #T_6fe1f_row6_col5 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_6fe1f_row6_col7 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_6fe1f_row7_col1 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_6fe1f_row7_col2 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_6fe1f_row7_col5 {
#   background-color: #2cb17e;
#   color: #f1f1f1;
# }
# #T_6fe1f_row7_col6 {
#   background-color: #2c728e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6fe1f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6fe1f_level0_col0" class="col_heading level0 col0" >Overall rank</th>
#       <th id="T_6fe1f_level0_col1" class="col_heading level0 col1" >Score</th>
#       <th id="T_6fe1f_level0_col2" class="col_heading level0 col2" >GDP per capita</th>
#       <th id="T_6fe1f_level0_col3" class="col_heading level0 col3" >Social support</th>
#       <th id="T_6fe1f_level0_col4" class="col_heading level0 col4" >Healthy life expectancy</th>
#       <th id="T_6fe1f_level0_col5" class="col_heading level0 col5" >Freedom to make life choices</th>
#       <th id="T_6fe1f_level0_col6" class="col_heading level0 col6" >Generosity</th>
#       <th id="T_6fe1f_level0_col7" class="col_heading level0 col7" >Perceptions of corruption</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fe1f_level0_row0" class="row_heading level0 row0" >Overall rank</th>
#       <td id="T_6fe1f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_6fe1f_row0_col1" class="data row0 col1" >-0.989096</td>
#       <td id="T_6fe1f_row0_col2" class="data row0 col2" >-0.801947</td>
#       <td id="T_6fe1f_row0_col3" class="data row0 col3" >-0.767465</td>
#       <td id="T_6fe1f_row0_col4" class="data row0 col4" >-0.787411</td>
#       <td id="T_6fe1f_row0_col5" class="data row0 col5" >-0.546606</td>
#       <td id="T_6fe1f_row0_col6" class="data row0 col6" >-0.047993</td>
#       <td id="T_6fe1f_row0_col7" class="data row0 col7" >-0.351959</td>
#     </tr>
#     <tr>
#       <th id="T_6fe1f_level0_row1" class="row_heading level0 row1" >Score</th>
#       <td id="T_6fe1f_row1_col0" class="data row1 col0" >-0.989096</td>
#       <td id="T_6fe1f_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_6fe1f_row1_col2" class="data row1 col2" >0.793883</td>
#       <td id="T_6fe1f_row1_col3" class="data row1 col3" >0.777058</td>
#       <td id="T_6fe1f_row1_col4" class="data row1 col4" >0.779883</td>
#       <td id="T_6fe1f_row1_col5" class="data row1 col5" >0.566742</td>
#       <td id="T_6fe1f_row1_col6" class="data row1 col6" >0.075824</td>
#       <td id="T_6fe1f_row1_col7" class="data row1 col7" >0.385613</td>
#     </tr>
#     <tr>
#       <th id="T_6fe1f_level0_row2" class="row_heading level0 row2" >GDP per capita</th>
#       <td id="T_6fe1f_row2_col0" class="data row2 col0" >-0.801947</td>
#       <td id="T_6fe1f_row2_col1" class="data row2 col1" >0.793883</td>
#       <td id="T_6fe1f_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_6fe1f_row2_col3" class="data row2 col3" >0.754906</td>
#       <td id="T_6fe1f_row2_col4" class="data row2 col4" >0.835462</td>
#       <td id="T_6fe1f_row2_col5" class="data row2 col5" >0.379079</td>
#       <td id="T_6fe1f_row2_col6" class="data row2 col6" >-0.079662</td>
#       <td id="T_6fe1f_row2_col7" class="data row2 col7" >0.298920</td>
#     </tr>
#     <tr>
#       <th id="T_6fe1f_level0_row3" class="row_heading level0 row3" >Social support</th>
#       <td id="T_6fe1f_row3_col0" class="data row3 col0" >-0.767465</td>
#       <td id="T_6fe1f_row3_col1" class="data row3 col1" >0.777058</td>
#       <td id="T_6fe1f_row3_col2" class="data row3 col2" >0.754906</td>
#       <td id="T_6fe1f_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_6fe1f_row3_col4" class="data row3 col4" >0.719009</td>
#       <td id="T_6fe1f_row3_col5" class="data row3 col5" >0.447333</td>
#       <td id="T_6fe1f_row3_col6" class="data row3 col6" >-0.048126</td>
#       <td id="T_6fe1f_row3_col7" class="data row3 col7" >0.181899</td>
#     </tr>
#     <tr>
#       <th id="T_6fe1f_level0_row4" class="row_heading level0 row4" >Healthy life expectancy</th>
#       <td id="T_6fe1f_row4_col0" class="data row4 col0" >-0.787411</td>
#       <td id="T_6fe1f_row4_col1" class="data row4 col1" >0.779883</td>
#       <td id="T_6fe1f_row4_col2" class="data row4 col2" >0.835462</td>
#       <td id="T_6fe1f_row4_col3" class="data row4 col3" >0.719009</td>
#       <td id="T_6fe1f_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_6fe1f_row4_col5" class="data row4 col5" >0.390395</td>
#       <td id="T_6fe1f_row4_col6" class="data row4 col6" >-0.029511</td>
#       <td id="T_6fe1f_row4_col7" class="data row4 col7" >0.295283</td>
#     </tr>
#     <tr>
#       <th id="T_6fe1f_level0_row5" class="row_heading level0 row5" >Freedom to make life choices</th>
#       <td id="T_6fe1f_row5_col0" class="data row5 col0" >-0.546606</td>
#       <td id="T_6fe1f_row5_col1" class="data row5 col1" >0.566742</td>
#       <td id="T_6fe1f_row5_col2" class="data row5 col2" >0

# %% [markdown]
# ### Correlation Matrix in Matplotlib
# - Matplotlib
# - [plt.matshow()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.matshow.html)

# %%
fig, ax = plt.subplots(figsize=(6,6))

# Change color using cmap
cp = ax.matshow(correlation_matrix, cmap='coolwarm')

ax.set_title('Correlation Matrix in Matplotlib')

# Annotate the values into the correlation plot
for (i, j), z in np.ndenumerate(correlation_matrix):
    ax.text(j, i, f'{z:0.2f}', ha='center', va='center')


feature_names = correlation_matrix.columns
# Set ticks and labels
ax.set_xticks(np.arange(len(feature_names)))  # Set the number of ticks equal to the number of features
ax.set_yticks(np.arange(len(feature_names)))

# Assign feature names as tick labels
ax.set_xticklabels(feature_names, rotation=90)  # Rotate x labels for readability
ax.set_yticklabels(feature_names)

#  Move the x-axis labels to the bottom
ax.xaxis.set_ticks_position('bottom')  # Set the x-ticks to be at the bottom
ax.xaxis.set_label_position('bottom')  # Ensure the label is also positioned at the bottom

# Add colorbar
fig.colorbar(cp, ax=ax, fraction=0.046, pad=0.04)

plt.show()

# %% [markdown]
# ### Correlation Matrix in Seaborn
# - Seaborn
# - sns.heatmap(df.corr())

# %%
# Correlation Matrix function in Seaborn
fig, ax= plt.subplots(figsize=(8,8))
cmap = plt.get_cmap('magma',30)
ax= sns.heatmap(correlation_matrix, annot=True, fmt="0.2f", square=True
               ,cmap=cmap, cbar_kws={"shrink": 0.8})
ax.set_title('Correlation Matrix in Seaborn', fontsize=13);

# annot=True: annotate values into the corr matrix
# cbar_kws={"shrink": 0.8} : change the size of the colorbar to 0.8 of the plot

# %% [markdown]
# ### Scatter Plot Matrix (SPLOM)

# %% [markdown]
# - Pandas
# - [pd.plotting.scatter_matrix()](https://pandas.pydata.org/docs/reference/api/pandas.plotting.scatter_matrix.html)

# %%
scatter_matrix_data= data[['Social support','Healthy life expectancy','Score','GDP per capita']]

# %%
pd.plotting.scatter_matrix(scatter_matrix_data, diagonal='hist', figsize=(10,10),
                           color='darkgreen', marker='.', alpha=0.6, s=80,
                           hist_kwds={'bins':15, 'color':'darkblue','edgecolor':'black'})
plt.suptitle('Scatter Matrix of Data', fontsize=15);

# diagonal: {hist, kde}

# %%
# For sake of simplicity, we use pair plot for only 4 attributes
pair_plot_data = data[['Social support','Healthy life expectancy','Score','GDP per capita', 'Group']]

# %% [markdown]
# - Seaborn
# - [sns.pairplot()](https://seaborn.pydata.org/generated/seaborn.pairplot.html)

# %%
# Pair Plot function in Seaborn
sns.pairplot(data=pair_plot_data, kind='scatter', diag_kws={'bins':20, 'color':'darkblue','edgecolor':'black'},
            plot_kws={'marker':'o','color':'darkred'}, height=3);
# kind: reg(regression line), hist(2d-hist), hex (hex plot), kde (kde), scatter(scatter plot)
# size: size of the plot

# %%
# Pair Plot function in Seaborn by different groups
sns.pairplot(data=pair_plot_data, hue='Group', palette='magma', height=2.5);

# %% [markdown]
# ## Visualization for one feature: Histogram, Box plot, Violin plot, Bee Swarm plot

# %% [markdown]
# ### Histogram

# %% [markdown]
# - X data: numeric variable
# - Function: Observe the distribution of X variable

# %%
histogram_data= data['GDP per capita']

# %% [markdown]
# - Pandas
# - [df.plot.hist()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.hist.html)

# %%
# Histogram function with Pandas
histogram_data.plot.hist(bins=40, color=['darkblue', 'darkgreen'], figsize=(10,4),
                        edgecolor='black', lw=1);

# %% [markdown]
# - Matplotlib
# - [plt.hist()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html)

# %%
# Histogram function with matplotlib
fig,ax= plt.subplots(figsize=(10,4))
ax.hist(histogram_data, bins=10, color='darkgreen',histtype='barstacked',
        edgecolor='black', label='GDP')
ax.legend(prop ={'size': 10});

# %% [markdown]
# - Seaborn
# - [sns.histplot()](https://seaborn.pydata.org/generated/seaborn.histplot.html)

# %%
# Histogram function with seaborn
ax=sns.histplot(data=histogram_data, bins=10, 
                color='darkblue', edgecolor='black', kde=True)

# %%
# If we want to see the distribution of several features in one graph, we can do it.
histogram_data= data[['GDP per capita', 'Score']]
histogram_data.sample(10)
# Out:
#      GDP per capita  Score
# 150           0.287  3.380
# 109           0.657  4.696
# 147           1.041  3.488
# 153           0.350  3.203
# 47            1.162  6.070
# 114           0.331  4.587
# 130           0.710  4.360
# 27            1.403  6.375
# 132           0.820  4.332
# 17            1.356  6.923

# %%
# Histogram function with Pandas
ax = histogram_data.plot.hist(bins=40, color=['darkblue', 'darkgreen'], figsize=(10,4),
                        edgecolor='black', lw=1)
# Add the legend with the title
ax.legend(['Score', 'GDP per capita'], title="Variables");

# %%
# Histogram function with matplotlib
fig,ax= plt.subplots(figsize=(10,4))
ax.hist(histogram_data['GDP per capita'], bins=10, color='darkgreen',histtype='barstacked',
        edgecolor='black', label='GDP')
ax.hist(histogram_data['Score'], bins=30, color='darkblue',histtype='barstacked',
        edgecolor='black', label='Score');


# Add the legend
ax.legend(prop ={'size': 10}, title="Variables");

# %%
# Histogram function with seaborn
sns.set_theme(rc={'figure.figsize': (10, 4)}, style='whitegrid')

# Plot the first histogram for 'Score'
ax = sns.histplot(x='Score', data=histogram_data, bins=30, 
                  color='darkgreen', edgecolor='black', kde=True, 
                  label='Score')

# Plot the second histogram for 'GDP per capita'
ax = sns.histplot(x='GDP per capita', data=histogram_data, bins=10, 
                  color='darkblue', edgecolor='black', kde=True, 
                  label='GDP per capita')

# Add the legend
plt.legend(title='Variables');

# %% [markdown]
# ### Box Plot

# %% [markdown]
# - X data: numeric variable
# - Function: Observe the spread by using metric quartiles (0.25,0.5, 0.75) and see the outliers

# %%
# Lets say, we want to see the variation of all numeric variables except for Overall rank and Score
boxplot_data= data.drop(['Overall rank','Country or region', 'Score'], axis=1)
boxplot_data.head(3)
# Out:
#    GDP per capita  Social support  Healthy life expectancy  \
# 0           1.340           1.587                    0.986
# 1           1.383           1.573                    0.996
# 2           1.488           1.582                    1.028
#
#    Freedom to make life choices  Generosity  Perceptions of corruption Group
# 0                         0.596       0.153                      0.393  High
# 1                         0.592       0.252                      0.410  High
# 2                         0.603       0.271                      0.341  High

# %% [markdown]
# - Pandas
# - [df.plot.box()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.box.html)

# %%
# Set colors for the box 
props = dict(boxes="darkblue", whiskers="black", medians="red", caps="black")
# Box plot function in Pandas
boxplot_data.plot.box(color=props, patch_artist=True, rot=45, figsize=(10,5));

# %%
df=boxplot_data
props = dict(boxes="darkblue", whiskers="black", medians="red", caps="black")
df.groupby(by='Group').boxplot(column='GDP per capita',patch_artist=True,
                               color=props,layout=(1,3), fontsize=15, figsize=(12,4));

# %% [markdown]
# - Matplotlib
# - [plt.boxplot()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.boxplot.html)

# %%
# Boxplot functions in Matplotlib 

# Ensure only numeric columns are included
numeric_data = boxplot_data.select_dtypes(include=['number'])

# Boxplot function in Matplotlib
fig, ax = plt.subplots(figsize=(10, 5))
ax.boxplot(numeric_data, widths=0.55, patch_artist=True, notch=True)
ax.set_title('Boxplot of Data', fontsize=17)
ax.set_xlabel('Numeric Variables', fontsize=12)
ax.set_ylabel('Quantiles of Values', fontsize=12);
ax.set_xticklabels(numeric_data.columns, rotation=90, ha='right', fontsize=10);

# width: width of the box
# patch_artist=True: Box is filled with color 
# notch = True: notch shape

# %% [markdown]
# - Seaborn
# - [sns.boxplot()](https://seaborn.pydata.org/generated/seaborn.boxplot.html)

# %%
# Boxplot funcion in Seaborn

# Set theme
sns.set_theme(rc={'figure.figsize': (10, 5)}, style='whitegrid')

seaborn_data = boxplot_data.drop(['Group'], axis=1)
# Boxplot function in Seaborn
ax = sns.boxplot(data=seaborn_data, linewidth=1, palette="Set2")

# Set title and labels for the plot
ax.set_title('Boxplot of Data', fontsize=17)
ax.set_xlabel('Numeric Variables', fontsize=12)
ax.set_ylabel('Quantiles of Values', fontsize=12)

# Set the correct number of ticks
ax.set_xticks(range(len(seaborn_data.columns)))

# Set the x-axis labels with rotation
ax.set_xticklabels(seaborn_data.columns, rotation=90, ha='right', fontsize=10);

# Adjust layout and show the plot
# plt.tight_layout()

# %% [markdown]
# ### Violin Plot

# %% [markdown]
# - X data: numeric variable
# - Function: same as Boxplot, but can even see the distribution of variable (using KDE method)

# %%
# We use same [numerical] data used for boxplot
violin_plot_data = boxplot_data.drop(['Group'], axis=1)

# %% [markdown]
# - Matplotlib
# - [plt.violinplot()](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.violinplot.html)

# %%
# Violin plot functions in Matplotlib
fig, ax = plt.subplots(figsize=(15, 5))

# Create the violin plot
violin = ax.violinplot(violin_plot_data, widths=0.7, bw_method=0.2,
                       showextrema=True, showmeans=True)

# Set title and labels for the plot
ax.set_title('Violin Plot of Data', fontsize=17)
ax.set_xlabel('Numeric Variables', fontsize=12)
ax.set_ylabel('Variation of Values', fontsize=12)

# Color of the violins
for pc in violin['bodies']:
    pc.set_facecolor('lightgreen')
    pc.set_edgecolor('black')
    pc.set_alpha(1)

# Ensure violin_plot_data is a DataFrame or structured data with named columns
# Set the correct number of ticks (use range starting from 1)
ax.set_xticks(range(1, len(violin_plot_data.columns) + 1))

# Set the x-axis labels with rotation for better readability
ax.set_xticklabels(violin_plot_data.columns, rotation=90, ha='right', fontsize=10);

# %% [markdown]
# ### Bee Swarm Plot  <a class="anchor" id="2.5"></a>

# %% [markdown]
# - X data: numeric variable
# - Function: same as Boxplot and Violin plot, but can even see the distribution dots of variable

# %%
# We use same data used for boxplot 
swarm_plot_data= data.drop(['Overall rank','Country or region', 'Score'],axis=1)

# %% [markdown]
# - Seaborn
# - [sns.swarmplot()](https://seaborn.pydata.org/generated/seaborn.swarmplot.html)

# %%
# Bee swarm plot function in Seaborn 
sns.set_theme(style='whitegrid') # theme of the graph
ax=sns.swarmplot(data=swarm_plot_data, size=3)
ax.set_title('Bee-Swarm Plot of Data', fontsize=17);

# Ensure violin_plot_data is a DataFrame or structured data with named columns
# Set the correct number of ticks (use range starting from 1)
ax.set_xticks(range(len(violin_plot_data.columns)))

# Set the x-axis labels with rotation for better readability
ax.set_xticklabels(violin_plot_data.columns, rotation=90, ha='right', fontsize=10);

# %%
# We can also combine the Violin plot with the Bee-swarm plot
sns.set_theme(rc={'figure.figsize':(20,6)}, style='whitegrid') 
ax=sns.violinplot(data=swarm_plot_data, inner=None)
ax=sns.swarmplot(data=swarm_plot_data, size=4, color='k', alpha=0.5)
ax.set_title('Bee-Swarm Plot of Data', fontsize=17);

# %% [markdown]
# ## Bar plot

# %% [markdown]
# ### Pandas bar plot for toy data

# %%
toy_data = {'Group': ['A', 'B', 'C', 'D', 'E'],
        'Score': [23, 17, 35, 29, 12]}

df = pd.DataFrame(toy_data)

df.plot.bar(x='Group', y='Score',  figsize=(8, 6), legend=False)

plt.ylabel('Values')
plt.xlabel('Category')
plt.title('Bar Plot of Categorical Features')
plt.xticks(rotation=0);

# %% [markdown]
# ### Pandas bar plot for real data

# %%
df = data.groupby('Group', as_index=False)['Score'].mean()
plt.figure(figsize=(8, 6)) 
sns.barplot(x='Group', y='Score', data=df, width=0.7)
plt.xlabel('Group')
plt.ylabel('Avegare value of Score for a group')
# Out:
# Text(0, 0.5, 'Avegare value of Score for a group')

# %% [markdown]
# ### Matplotlib bar plot for toy data

# %%
toy_data = {'Category': ['A', 'B', 'C', 'D', 'E'],
        'Values': [23, 17, 35, 29, 12]}

df = pd.DataFrame(toy_data)

# Create a bar plot
plt.figure(figsize=(8, 6))
plt.bar(df['Category'], df['Values'])
plt.xlabel('Category')
plt.ylabel('Values')
plt.title('Bar Plot of Categorical Features')
# Out:
# Text(0.5, 1.0, 'Bar Plot of Categorical Features')

# %% [markdown]
# ### Matplotlib bar plot for real data

# %%
df = data.groupby('Group', as_index=False)['Score'].mean()
plt.figure(figsize=(8, 6))
plt.bar(df['Group'], df['Score'])
plt.xlabel('Group')
plt.ylabel('Avegare value of Score for a group')
plt.title('Bar Plot of Categorical Features')
# Out:
# Text(0.5, 1.0, 'Bar Plot of Categorical Features')

# %% [markdown]
# ### Seaborn bar plot for toy data

# %%
toy_data = {'Category': ['A', 'B', 'C', 'D', 'E'],
        'Values': [23, 17, 35, 29, 12]}

df = pd.DataFrame(toy_data)

# Create a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x='Category', y='Values', data=df)
plt.xlabel('Category')
plt.ylabel('Values')
plt.title('Bar Plot of Categorical Features');

# %% [markdown]
# ### Seaborn bar plot for real data

# %%
df = data.groupby('Group', as_index=False)['Score'].mean()
plt.figure(figsize=(8, 6)) 
sns.barplot(x='Group', y='Score', data=df, width=0.7)
plt.xlabel('Group')
plt.ylabel('Avegare value of Score for a group');

# %% [markdown]
# ## Visualization for two features: Scatter plot, Joint plot

# %% [markdown]
# ### Scatter Plot <a class="anchor" id="3.2"></a>

# %% [markdown]
# - X data: numeric variable
# - Y data: numeric variable

# %%
# Scatter plot between x:GDP and y:happiness score 
scatter_plot_data= data[['GDP per capita','Perceptions of corruption','Score']]
scatter_plot_data.head()
# Out:
#    GDP per capita  Perceptions of corruption  Score
# 0           1.340                      0.393  7.769
# 1           1.383                      0.410  7.600
# 2           1.488                      0.341  7.554
# 3           1.380                      0.118  7.494
# 4           1.396                      0.298  7.488

# %% [markdown]
# - Pandas
# - [df.plot.scatter()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.scatter.html)

# %%
# Scatter plot function in Pandas 
scatter_plot_data.plot.scatter(x='GDP per capita', y='Score', color='darkgreen', figsize=(10,5));

# %%
# We can make multiple scatter plot at the same time
fig, ax= plt.subplots(ncols=2)
scatter_plot_data.plot.scatter(x='GDP per capita', y='Score',marker='^',s=70,
                               color='darkgreen',ax=ax[0])
scatter_plot_data.plot.scatter(x='Perceptions of corruption', y='Score',marker='*',s=70, 
                               color='navy',ax=ax[1])
fig.tight_layout();

# %% [markdown]
# - Matplotlib
# - [plt.scatter()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html)

# %%
fig,ax= plt.subplots(figsize=(10,5))
ax.scatter(x='GDP per capita', y='Score', data= scatter_plot_data, marker='^',
          s=80, c='GDP per capita', edgecolors='black', alpha=0.5)
ax.set_xlabel('GDP')
ax.set_ylabel('Happiness score');

# s: size of marker
# c: color by variable

# %% [markdown]
# - Seaborn
# - [sns.scatterplot()](https://seaborn.pydata.org/generated/seaborn.scatterplot.html)

# %%
sns.scatterplot(x='GDP per capita', y='Score', hue='GDP per capita',data= scatter_plot_data,
                marker='^', s=80, edgecolor='black', alpha=0.8);

# %% [markdown]
# ### Joint Plot

# %% [markdown]
# - X data: numeric variable
# - Y data: numeric variable
# - Function: Combine scatter plot of X,Y data,and combine with histograms of each

# %%
# Imagine, we want to see the relationship between Social support and Life expectancy and distribution of each one 
# And we also interested in how they are related by groups
joint_plot_data= pair_plot_data

# %% [markdown]
# - Seaborn
# - [sns.jointplot()](https://seaborn.pydata.org/generated/seaborn.jointplot.html)

# %%
# Joint Plot in Seaborn
sns.jointplot(x='Social support', y='Healthy life expectancy',data=joint_plot_data, 
              xlim=(0.3,1.65), ylim=(0.1,1.2),color='darkblue',marginal_kws={"bins": 20}, kind='reg');

# kind: reg(regression line), hist(2d-hist), hex (hex plot), kde (kde)
# marginal_kws : marginal plots on the side

# %%
# Joint Plot in Seaborn by groups
sns.jointplot(x='Social support', y='Healthy life expectancy',data=joint_plot_data, 
              xlim=(0.3,1.65), ylim=(0.1,1.2),hue='Group');
